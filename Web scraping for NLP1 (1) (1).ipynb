# %%
import requests
import re
from bs4 import BeautifulSoup
import os
from urllib.parse import urljoin

try:
    url = 'https://www.dcgk.de/en/declarations-of-compliance.html'
    reqs = requests.get(url)
    soup = BeautifulSoup(reqs.text, 'html.parser')
    text=[]
    for link in soup.find_all('a'):
        text.append(link)

    c_url=[]
    for i in text:
        urls = re.findall('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', str(i))
        c_url.append(urls)
    res = [ele for ele in c_url if ele != []]
    flatList = [ item for elem in res for item in elem]
    for i in flatList[15::]:
        print(i)
        urls = i
        url = i
        url = url.split('//')
        url=url[1]
        url=url.split('/')
        url=url[0]
        #print(url)
        os.mkdir('E:/Data science/stocks/doc/pdf_extract/' + url)
        #If there is no such folder, the script will create one automatically
        folder_location = 'E:/Data science/stocks/doc/pdf_extract/'+ url
        #os.mkdir(r'/home/sudharsan_shankar/Documents' + url )
        #if not os.path.exists(folder_location):os.mkdir(folder_location)
    
        response = requests.get(urls)
        soup= BeautifulSoup(response.text, "html.parser")     
        for link in soup.select("a[href$='.pdf']"):
            #Name the pdf files using the last portion of each link which are unique in this case
            filename = os.path.join(folder_location,link['href'].split('/')[-1])
            with open(filename, 'wb') as f:
                f.write(requests.get(urljoin(urls,link['href'])).content)
            
except (ConnectionError,ConnectionResetError):
    print('error')

# %%
import re

def extractMax(input):
    numbers = re.findall('\d+',input)
    numbers = map(int,numbers)
    print(max(numbers))

# %%
website=['https://www.fuchs.com/group/the-company/corporate-governance/articles-of-association-and-declaration-of-compliance/','https://www.telekom.com/en/investor-relations/investor-relations/declaration-of-conformity-pursuant-to-161-of-the-german-stock-corporation-act-aktiengesetz-aktg--352918']
pdf=['Declaration_of_compliance','dl-cc-erklaerung']

# %%
pdf = ['Declaration_of_Conformity_','entsprechungserklaerung-dez','Declaration_of_Compliance_','Declaration-of-Compliance_','Declaration_of_Compliance_','Entsprechenserklaerung_en']
website = ['https://www.db.com/ir/en/documents.htm','https://www.deutsche-boerse.com/dbg-en/investor-relations/corporate-governance/declaration-of-conformity','https://ir.deliveryhero.com/websites/delivery/English/4500/declaration-of-compliance.html','https://ir.deutsche-wohnen.com/websites/dewohnen/English/4400/declaration-of-conformity.html','https://www.freseniusmedicalcare.com/en/investors/corporate-governance/declaration-of-compliance/','https://www.fresenius.com/corporate-governance']

# %%
import os
import requests
from urllib.parse import urljoin
from bs4 import BeautifulSoup

for i,j in zip(website):      
    url = '%s'%i

    #If there is no such folder, the script will create one automatically
    folder_location = "E:\\Data science\\stocks\\pdfs\\"
    if not os.path.exists(folder_location):
        os.mkdir(folder_location)

    response = requests.get(url)
    soup= BeautifulSoup(response.text, "html.parser")
    try:
        for link in soup.select("a[href*='%s']"%j):
            #Name the pdf files using the last portion of each link which are unique in this case
            filename = os.path.join(folder_location,link['href'].split('/')[-1])
            print(link)
            extractMax(link)
    except TypeError:
        print('')
    
    with open(filename, 'wb') as f:
        f.write(requests.get(urljoin(url,link['href'])).content)
        f.close()
        
    name = (url.split('.com')[0]).split('.')[1]+'.pdf'
    print(name)
    os.rename('E:\\Data science\\stocks\\pdfs\\%s'%link['href'].split('/')[-1], 'E:\\Data science\\stocks\\pdfs\\%s'%name )
# Out:
# <a href="/ir/en/download/Declaration_of_Conformity_2020_EN.pdf" target="_blank">PDF</a>
#
# db.pdf
# <a class="icon download_pdf" href="/resource/blob/2362496/ff15eb5e5d4d9322c407dbba2b345f30/data/entsprechungserklaerung-dez2020_en.pdf" target="_blank"><span><span>3 December 2020: Declaration of Conformity according § AktG 161 </span> [<span class="download-type">PDF</span><span class="download-size">, 78.49 kB</span>]</span></a>
#
# deutsche-boerse.pdf
# <a href="/download/companies/delivery/CorporateGovernance/Declaration_of_Compliance_2020.pdf" target="_blank"><span class="last-news__item__title">Declaration of Compliance 2020</span></a>
#
# deliveryhero.pdf
# <a class="link--invert download__link" download="" href="/download/companies/dewohnen/CorporateGovernance/2019_Declaration-of-Compliance_final.pdf" target="_blank">
# <div class="download__data">
# <svg aria-hidden="true" class="download__icon">
# <use class="download__icon-attribute" xlink:href="#download"></use>
# </svg>
# <span class="download__main-keywords">Declaration of Compliance, December 2019</span>
# </div>
# <div class="download__date-container">
# <span class="download__date"> </span>
# </div>
# </a>
#
# deutsche-wohnen.pdf
# <a href="/fileadmin/data/com/pdf/investors/Corporate_Governance/Declaration_of_Compliance/FME_Declaration_of_Compliance_December_2020.pdf" target="_blank"><picture><source media="(max-width: 767px)" srcset="/fileadmin/_processed_/c/0/csm_FME_Declaration_of_Compliance_December_2020_a44428a94c.png, /fileadmin/_processed_/c/0/csm_FME_Declaration_of_Compliance_December_2020_08e71c7ad3.png 2x"/><source media="(min-width: 768px)" srcset="/fileadmin/_processed_/c/0/csm_FME_Declaration_of_Compliance_December_2020_08e71c7ad3.png, /fileadmin/_processed_/c/0/csm_FME_Declaration_of_Compliance_December_2020_8ea82b0233.png 2x"/><img alt="" border="0" class="" loading="lazy" src="/fileadmin/_processed_/c/0/csm_FME_Declaration_of_Compliance_December_2020_b449b3255b.png"/></picture></a>
#
# freseniusmedicalcare.pdf
# <a class="icon il pdf" href="/media/2020_12_Entsprechenserklaerung_en.pdf">Declaration of Conformity of Fresenius SE &amp; Co. KGaA as of December 20, 2020 <font>(PDF, 100 KB)</font></a>
#
# fresenius.pdf

# %%
import os
import requests
import pandas as pd  
from urllib.parse import urljoin
from bs4 import BeautifulSoup

# %%
def get_lates_pdf_from_link(url_list, keyword_list, file_path):
    
    if not os.path.exists(file_path):
        os.mkdir(folder_location)
    
    for url in url_list:
        try:
            response = requests.get(url, timeout=2)
            soup= BeautifulSoup(response.text, "html.parser")
            test = 1
        except:
            print("Not able to load following url:\n", url, "\n\n")
            test = 0
    
        if test == 1:    
            try:
                for key in keyword_list:
                    links = soup.select("a[href*='%s']"%key)
                    if len(links) > 0:
                        df_chs = pd.DataFrame(columns = ["year", "link"])
                        for link in links:
                            #Name the pdf files using the last portion of each link which are unique in this case
                            last_links = link['href'].split('/')[-1]
                            for split_char in ['_','(',')','-', '.']:
                                last_links = ' '.join(last_links.split(split_char))
                            year = [int(num) for num in last_links.split() if (num.isdigit()) & (len(num) == 4)]
                            if len(year) > 0:
                                df_chs.loc[len(df_chs)] = [year[0], link['href']]
                        if len(df_chs) > 0:
                            df_chs.sort_values("year", axis=0, ascending=False, inplace=True)
#                             print(df_chs.head(10))
                            filename = str(df_chs.iloc[0,1])
                            filename = filename.split("/")[-1].split(".pdf")[0] + ".pdf"
                            link = str(df_chs.iloc[0,1])
                        else:
                            filename = ''
                        break  
                    else:
                        filename = ''
            except TypeError:
                filename = ''

            if len(filename) > 5:
                with open(folder_location+filename, 'wb') as f:
                    f.write(requests.get(urljoin(url,link)).content)
                    f.close()

# %%
df = pd.read_csv(r"D:\New_folder\pdf\keywords.csv")
keywords = df["keywords"].dropna().tolist()
#url_list = df["company_link"].dropna().tolist()
# url_list = flatList
url_list = ['https://www.fraport.com/en/investors/corporate-governance.html']
folder_location = r"D:\New_folder\pdf\\"

# %%
get_lates_pdf_from_link(url_list, keywords, folder_location)
# Out:
#    year                                               link
# 0  2010  /content/dam/fraport-company/documents/investo...
# 1  2010  /content/dam/fraport-company/documents/investo...
# 2  2009  /content/dam/fraport-company/documents/investo...
# 5  2009  /content/dam/fraport-company/documents/investo...
# 3  2008  /content/dam/fraport-company/documents/investo...
# 4  2007  /content/dam/fraport-company/documents/investo...
# 6  2005  /content/dam/fraport-company/documents/investo...
# 7  2005  /content/dam/fraport-company/documents/investo...
# 8  2004  /content/dam/fraport-company/documents/investo...
# 9  2003  /content/dam/fraport-company/documents/investo...

# %%
url_list
# Out:
# ['https://www.fraport.com/en/investors/corporate-governance.html']

# %%
import requests
import re
from bs4 import BeautifulSoup
import os
from urllib.parse import urljoin

url = 'https://www.dcgk.de/en/declarations-of-compliance.html'
reqs = requests.get(url)
soup = BeautifulSoup(reqs.text, 'html.parser')
text=[]
for link in soup.find_all('a'):
    text.append(link)

c_url=[]
for i in text:
    urls = re.findall('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', str(i))
    c_url.append(urls)
res = [ele for ele in c_url if ele != []]
flatList = [ item for elem in res for item in elem]
del flatList[0:4]
flatList
# Out:
# ['http://www.adidas-group.com/en/investors/corporate-governance/declaration-compliance/',
#  'https://www.allianz.com/en/about_us/management/corporate-governance/declaration-of-conformity/',
#  'https://www.basf.com/global/en/investors/basf-at-a-glance/corporate-governance/declarations.html',
#  'http://www.bayer.com/en/Corporate-Governance.aspx',
#  'https://www.bmwgroup.com/en/company/company-portrait.html',
#  'https://www.continental-corporation.com/en/company/corporate-governance/principles-and-declarations/corporate-governance-principles-13402',
#  'https://www.covestro.com/en/company/management/corporate-governance',
#  'https://www.daimler.com/company/corporate-governance/declarations/',
#  'https://ir.deliveryhero.com/websites/delivery/English/4500/declaration-of-compliance.html',
#  'https://www.db.com/ir/en/documents.htm',
#  'http://deutsche-boerse.com/dbg/dispatch/en/kir/dbg_nav/investor_relations/15_Corporate_Governance/50_Declaration_of_Conformity',
#  'http://www.dpdhl.com/en/investors/corporate_governance/declaration_of_conformity.html',
#  'http://www.telekom.com/declaration-of-conformity',
#  'https://ir.deutsche-wohnen.com/websites/dewohnen/English/4400/declaration-of-compliance.html',
#  'https://www.eon.com/en/about-us/corporate-governance/declaration-of-compliance.html',
#  'http://www.freseniusmedicalcare.com/en/investors/corporate-governance/declaration-of-compliance/',
#  'https://www.fresenius.com/corporate-governance',
#  'https://www.heidelbergcement.com/en/declaration-of-corporate-governance',
#  'https://www.henkel.com/investors-and-analysts/corporate-governance',
#  'https://www.infineon.com/cms/en/about-infineon/investor/corporate-governance/',
#  'https://www.linde.com/about-linde/corporate-governance',
#  'https://www.merckgroup.com/en/investors/corporate-governance/reports.html',
#  'https://www.mtu.de/investor-relations/corporate-governance/compliance-statement/',
#  'https://www.munichre.com/en/company/about-munich-re/corporate-governance/declarations-of-conformity-with-gcgc-dcgk.html',
#  'https://www.group.rwe/en/investor-relations/corporate-governance/statement-of-compliance',
#  'https://www.sap.com/investors/en/governance.html',
#  'https://new.siemens.com/global/en/company/investor-relations/corporate-governance.html',
#  'https://www.siemens-energy.com/global/en/company/investor-relations/corporate-governance.html',
#  'http://www.volkswagenag.com/en/InvestorRelations/corporate-governance/declaration-of-conformity.html',
#  'https://investoren.vonovia.de/websites/vonovia/English/7025/declaration-of-conformity.html',
#  'https://www.aareal-bank.com/en/about-us/corporate-governance/declaration-of-compliance/',
#  'https://www.airbus.com/company/corporate-governance.html',
#  'https://www.aixtron.com/en/investors/corporate-governance/principles',
#  'https://alstria.com/company/',
#  'https://www.aroundtown.de/investor-relations/corporate-governance/',
#  'https://www.aurubis.com/en/about-aurubis/distribution-page-corporate-governance',
#  'https://www.bechtle.com/de-en/about-bechtle/investors/corporate-governance',
#  'https://www.beiersdorf.com/investors/corporate-governance/declaration-of-compliance',
#  'https://www.brenntag.com/corporate/en/investor-relations/corporate-governance/compliance-statement/',
#  'https://www.cancom.com/corporate-governance/?_ga=2.50171822.908792205.1610362483-416397059.1610362483',
#  'https://www.zeiss.com/meditec-ag/investor-relations/declaration-on-corporate-management.html',
#  'https://www.commerzbank.de/en/hauptnavigation/aktionaere/governance_/corporate_governace_1.html',
#  'https://www.cgm.com/corp/ueber_uns_1/investor_relations/coporate_governance/entsprechungserklaerung/entsprechenserklaerung.en.jsp',
#  'https://corporate.eventim.de/en/investor-relations/corporate-governance/',
#  'https://investor-relations.lufthansagroup.com/en/corporate-governance/corporate-governance-declaration-section-289f-hgb/declaration-of-compliance-section-161-aktg.html',
#  'https://www.durr-group.com/en/investor-relations/corporate-governance/declaration-on-corporate-governance/',
#  'https://corporate.evonik.de/en/investor-relations/corporate-governance/german-corporate-governance-code',
#  'https://www.evotec.com/en/invest/corporate-governance',
#  'https://www.fraport.com/en/investors/corporate-governance.html',
#  'https://www.freenet-group.de/investor/corporate-governance/index.html',
#  'https://www.fuchs.com/group/the-company/corporate-governance/articles-of-association-and-declaration-of-compliance/',
#  'http://www.gea.com/en/investor-relations/corporate-governance/statement-of-the-board/index.jsp',
#  'https://www.gerresheimer.com/en/investor-relations/corporate-governance/statements-of-compliance.html',
#  'https://www.grandcityproperties.com/about-us/corporate-governance/',
#  'https://www.hannover-re.com/200801/declaration-of-conformity',
#  'http://www.hella.com/hella-com/en/Declaration-of-Conformity-10446.html',
#  'https://ir.hellofreshgroup.com/websites/hellofresh/English/4000/corporate-governance.html',
#  'http://www.hochtief.com/hochtief_en/172.jhtml',
#  'https://group.hugoboss.com/en/company/corporate-governance/declaration-of-compliance/',
#  'https://www.kpluss.com/en-us/about-ks/governance/index.html',
#  'https://www.kiongroup.com/en/About-us/Management/',
#  'https://ir.knorr-bremse.com/websites/Knorrbremse_ir/English/7000/corporate-governance.html',
#  'https://lanxess.com/en/Investors/Corporate-Governance',
#  'https://www.leg-wohnen.de/en/corporation/investor-relations/corporate-governance/corporate-governance-codex-compliance-statement/',
#  'https://www.metroag.de/en/company/corporate-governance',
#  'https://www.morphosys.com/media-and-investors/corporate-governance',
#  'https://ir.nemetschek.com/websites/nemetschek/English/5100/declaration-of-conformity.html',
#  'https://www.osram-group.com/en/our-company/our-management/corporate-governance',
#  'https://www.prosiebensat1.de/en/investor-relations/corporate-governance/management-declaration',
#  'https://about.puma.com/en/investor-relations/corporate-governance',
#  'https://corporate.qiagen.com/investor-relations/corporate-governance/governance-codes',
#  'https://www.rational-online.com/en_gb/company/investor-relations/corporate-governance/index.php',
#  'https://www.rheinmetall.com/en/rheinmetall_ag/group/corporategovernance_4/entsprechenserklaerung_2/index.php',
#  'https://www.sartorius.com/en/company/about-sartorius-ag/compliance',
#  'https://www.scout24.com/en/Investor-Relations/Corporate-Governance.aspx',
#  'https://shop-apotheke-europe.com/en/investorrelations/governance/',
#  'https://www.corporate.siemens-healthineers.com/investor-relations/corporate-governance',
#  'https://www.siltronic.com/en/investors/corporate-governance.html',
#  'https://investors.softwareag.com/en/corporate-governance/compliance-declaration',
#  'http://ir.stroeer.com/websites/stroeer/English/6200/declaration-of-compliance.html',
#  'http://www.symrise.com/investors/corporate-governance/declaration-of-compliance/',
#  'http://www.tag-ag.com/en/investor-relations/corporate-governance/declaration-of-conformity',
#  'https://ir.teamviewer.com/websites/teamviewer/English/40/corporate-governance.html',
#  'https://www.telefonica.de/investor-relations-en/corporate-governance/declarations-and-articles.html',
#  'https://www.thyssenkrupp.com/en/company/management/corporate-governance/declaration-of-conformity.html',
#  'https://ir.uniper.energy/websites/uniper/English/6500/corporate-governance-policy.html',
#  'https://www.united-internet.de/en/investor-relations/corporate-governance.html',
#  'https://www.varta-ag.com/en/investor-relations/corporate-governance',
#  'https://www.wacker.com/cms/en-de/about-wacker/investor-relations/corporate-governance/declaration-of-conformity.html',
#  'https://corporate.zalando.com/en/company/corporate-governance']

# %%
"dec compliance 3003".split()
# Out:
# ['dec', 'compliance', '3003']

# %%
link['href']
# Out:
# 'https://wwwfuchscom-94ba.kxcdn.com/fileadmin/Home/Contentseiten/Corporate_Governance/Entsprechenserklaerung_EN/Declaration_of_compliance__2017_.pdf'

# %%
response = requests.get('https://www.basf.com/global/en/investors/basf-at-a-glance/corporate-governance/declarations.html', timeout=2)

# %%
links = soup.select("a[href]")
for i,j in enumerate(links):
    if "entsprechungserklaerung" in str(j['href']):
        print(j['href'])
    else:
        print("--------------------", j['href'])
        
    
    
# for item in soup.select('.emblem'):
#     links = item['href']
#     print(links)
# Out:
# -------------------- #main-content
# -------------------- /en.html
# -------------------- https://www.fraport-bulgaria.com/en.html
# -------------------- https://www.fraport-greece.com/
# -------------------- https://www.fraport-slovenija.si/
# -------------------- https://www.fraport-usa.com/
# -------------------- https://www.jobs-fraport.de/?locale=en_US
# -------------------- /de.html
# -------------------- /en.html
# -------------------- /en/our-group.html
# -------------------- /en/our-group.html
# -------------------- /en/our-group/responsibility1.html
# -------------------- /en/our-group/responsibility1.html
# -------------------- /en/our-group/responsibility1/sustainability-concept.html
# -------------------- /en/our-group/responsibility1/organization-strategy-goals.html
# -------------------- /en/our-group/responsibility1/values-and-principles.html
# -------------------- /en/our-group/responsibility1/stakeholder-dialog.html
# -------------------- /en/our-group/responsibility1/indices-and-awards.html
# -------------------- https://www.fraport.com/en/newsroom/media-center/publications.html#responsibility
# -------------------- /en/investors/contact.html
# -------------------- /en/our-group/about-us.html
# -------------------- /en/our-group/about-us.html
# -------------------- /en/our-group/about-us/executive-board.html
# -------------------- /en/our-group/about-us/supervisory-board-and-economic-advisory-board-.html
# -------------------- /en/our-group/about-us/facts---figures.html
# -------------------- /en/our-group/about-us/our-history.html
# -------------------- /en/our-group/goals-and-values.html
# -------------------- /en/our-group/goals-and-values.html
# -------------------- /en/our-group/goals-and-values/mission-statement-and-strategy.html
# -------------------- /en/our-group/goals-and-values/compliance.html
# -------------------- /en/our-group/goals-and-values/diversity.html
# -------------------- /en/our-group/responsibility.html
# -------------------- /en/our-group/responsibility.html
# -------------------- /en/our-group/responsibility/sustainability-concept.html
# -------------------- /en/our-group/responsibility/organization-strategy-goals.html
# -------------------- /en/our-group/responsibility/values-and-principles.html
# -------------------- /en/our-group/responsibility/stakeholder-dialog.html
# -------------------- /en/our-group/responsibility/indices-and-awards.html
# -------------------- https://www.fraport.com/en/newsroom/media-center/publications.html#responsibility
# -------------------- /en/investors/contact.html
# -------------------- /en/our-group/our-airports-and-subsidiaries.html
# -------------------- /en/our-group/management-systems.html
# -------------------- /en/our-group/management-systems.html
# -------------------- /en/our-group/management-systems/occupational-health-and-safety.html
# -------------------- /en/our-group/management-systems/quality-management.html
# -------------------- /en/our-group/management-systems/safety-management-system.html
# -------------------- /en/our-group/our-airports-and-subsidiaries.html
# -------------------- /en/our-group/our-airports-and-subsidiaries.html
# -------------------- /en/our-group/responsibility.html
# -------------------- /en/our-group/responsibility.html
# -------------------- /en/business-areas.html
# -------------------- /en/business-areas.html
# -------------------- /en/business-areas/operations.html
# -------------------- /en/business-areas/operations.html
# -------------------- /en/business-areas/operations/airside-and-terminal-operations.html
# -------------------- /en/business-areas/operations/ground-handling.html
# -------------------- /en/business-areas/operations/airport-charges.html
# -------------------- /en/business-areas/operations/suppliers.html
# -------------------- /en/business-areas/operations/medical-center.html
# -------------------- /en/business-areas/operations/ground-services-equipment.html
# -------------------- /en/business-areas/operations/corporate-safety-and-security.html
# -------------------- /en/business-areas/operations/cargocity-frankfurt0.html
# -------------------- /en/business-areas/consulting.html
# -------------------- /en/business-areas/consulting.html
# -------------------- /en/business-areas/consulting/training.html
# -------------------- /en/business-areas/services/real-estate0/real-estate-consulting.html
# -------------------- /en/business-areas/constructions.html
# -------------------- /en/business-areas/constructions.html
# -------------------- /en/business-areas/constructions/terminal-3.html
# -------------------- /en/business-areas/constructions/airport-expansion.html
# -------------------- /en/business-areas/constructions/fras-economic-contribution.html
# -------------------- /en/business-areas/constructions/fra-gateway-to-the-world.html
# -------------------- /en/business-areas/services.html
# -------------------- /en/business-areas/services.html
# -------------------- /en/business-areas/services/parking-management.html
# -------------------- /en/business-areas/services/retailing-and-advertising.html
# -------------------- /en/business-areas/services/real-estate0.html
# -------------------- /en/business-areas/services/purchasing-and-contracting.html
# -------------------- /en/business-areas/services/coworking.html
# -------------------- /en/business-areas/services/id-cards-and-authorization-services.html
# -------------------- /en/business-areas/services/it-services.html
# -------------------- /en/business-areas/services/vip-services.html
# -------------------- /en/business-areas/services/real-estate0/rental-properties/locking-system-management.html
# -------------------- /en/business-areas/services/real-estate0/energy-management.html
# -------------------- /en/business-areas/operations.html
# -------------------- /en/business-areas/operations.html
# -------------------- /en/business-areas/constructions.html
# -------------------- /en/business-areas/constructions.html
# -------------------- /en/investors.html
# -------------------- /en/investors.html
# -------------------- /en/investors/the-fraport-share.html
# -------------------- /en/investors/annual-general-meeting.html
# -------------------- /en/investors/traffic-figures.html
# -------------------- /en/investors/creditor-relations.html
# -------------------- /en/investors/corporate-governance.html
# -------------------- /en/investors/ad-hoc-releases.html
# -------------------- /en/investors/events.html
# -------------------- /en/investors/publications.html
# -------------------- /en/investors/contact.html
# -------------------- https://irpages2.equitystory.com/websites/fraport_responsive/English/9910/mail-and-order-service.html?iframe=true
# -------------------- /en/investors/traffic-figures.html
# -------------------- /en/investors/traffic-figures.html
# -------------------- /en/investors/events.html
# -------------------- /en/investors/events.html
# -------------------- /en/environment.html
# -------------------- /en/environment.html
# -------------------- /en/environment/environmental-management.html
# -------------------- /en/environment/climate-protection.html
# -------------------- /en/environment/climate-protection.html
# -------------------- /en/environment/climate-protection/air-quality.html
# -------------------- /en/environment/noise-abatement.html
# -------------------- /en/environment/environmental-aspects.html
# -------------------- /en/environment/climate-protection.html
# -------------------- /en/environment/climate-protection.html
# -------------------- /en/environment/noise-abatement.html
# -------------------- /en/environment/noise-abatement.html
# -------------------- /en/newsroom.html
# -------------------- /en/newsroom.html
# -------------------- /en/newsroom/contacts.html
# -------------------- /en/newsroom/media-center.html
# -------------------- /en/newsroom/media-center.html
# -------------------- /en/newsroom/media-center/photo-library.html
# -------------------- /en/newsroom/media-center/publications.html
# -------------------- /en/newsroom/media-center/footage-media-archive.html
# -------------------- /en/newsroom/media-center/infographics.html
# -------------------- /en/newsroom/filming-and-photography-at-frankfurt-airport-.html
# -------------------- /en/newsroom/pressreleases.html
# -------------------- /en/newsroom/servicenews.html
# -------------------- /en/newsroom/contacts.html
# -------------------- /en/newsroom/contacts.html
# -------------------- /en/newsroom/media-center.html
# -------------------- /en/newsroom/media-center.html
# -------------------- https://www.jobs-fraport.de/?locale=en_US
# -------------------- https://www.fraport-bulgaria.com/en.html
# -------------------- https://www.fraport-greece.com/
# -------------------- https://www.fraport-slovenija.si/
# -------------------- https://www.fraport-usa.com/
# -------------------- /en/investors.html
# -------------------- /en.html
# -------------------- /en/investors.html
# -------------------- https://www.dcgk.de/en/
# -------------------- /content/dam/fraport-company/documents/konzern/eng/2020%2009%2008%20Satzung%20ENGLISCH%20final.pdf/_jcr_content/renditions/original.media_file.download_attachment.file/2020%2009%2008%20Satzung%20ENGLISCH%20final.pdf
# -------------------- /content/dam/fraport-company/documents/investoren/eng/corporate-governance/Joint%20Statement%20on%20Corporate%20Governance%202020.pdf/_jcr_content/renditions/original.media_file.download_attachment.file/Joint%20Statement%20on%20Corporate%20Governance%202020.pdf
# -------------------- /content/dam/fraport-company/documents/investoren/eng/corporate-governance/joint-statement-on-corporate-governance-2019_.pdf/_jcr_content/renditions/original.media_file.download_attachment.file/joint-statement-on-corporate-governance-2019_.pdf
# -------------------- /content/dam/fraport-company/documents/investoren/eng/corporate-governance/joint-statement-on-corporate-governance-2018.pdf/_jcr_content/renditions/original.media_file.download_attachment.file/joint-statement-on-corporate-governance-2018.pdf
# -------------------- /content/dam/fraport-company/documents/investoren/eng/corporate-governance/joint-statement-of-corporate-governance-2017.pdf/_jcr_content/renditions/original.media_file.download_attachment.file/joint-statement-of-corporate-governance-2017.pdf
# -------------------- /content/dam/fraport-company/documents/investoren/eng/corporate-governance/joint-statement-on-corporate-governance-2016.pdf/_jcr_content/renditions/original.media_file.download_attachment.file/joint-statement-on-corporate-governance-2016.pdf
# -------------------- /content/dam/fraport-company/documents/investoren/eng/corporate-governance/fraport_gb-2015_e_ezu.pdf/_jcr_content/renditions/original.media_file.download_attachment.file/fraport_gb-2015_e_ezu.pdf
# -------------------- /content/dam/fraport-company/documents/investoren/eng/corporate-governance/2020_Entsprechenserkl%C3%A4rung.pdf/_jcr_content/renditions/original.media_file.download_attachment.file/2020_Entsprechenserkl%C3%A4rung.pdf
# -------------------- /content/dam/fraport-company/documents/investoren/eng/corporate-governance/entsprechenserkla-rung_2019_en_clean.pdf/_jcr_content/renditions/original.media_file.download_attachment.file/entsprechenserkla-rung_2019_en_clean.pdf
# -------------------- /content/dam/fraport-company/documents/investoren/eng/corporate-governance/compliance_statement_2018.pdf/_jcr_content/renditions/original.media_file.download_attachment.file/compliance_statement_2018.pdf
# -------------------- /content/dam/fraport-company/documents/investoren/eng/corporate-governance/entsprechenserkla-rung_2017_en.pdf/_jcr_content/renditions/original.media_file.download_attachment.file/entsprechenserkla-rung_2017_en.pdf
# -------------------- /content/dam/fraport-company/documents/investoren/eng/corporate-governance/entsprechenserkla-rung_2016_en.pdf/_jcr_content/renditions/original.media_file.download_attachment.file/entsprechenserkla-rung_2016_en.pdf
# -------------------- /content/dam/fraport-company/documents/investoren/eng/corporate-governance/entsprechenserkla-rung_2015_en.pdf/_jcr_content/renditions/original.media_file.download_attachment.file/entsprechenserkla-rung_2015_en.pdf
# -------------------- /content/dam/fraport-company/documents/investoren/eng/corporate-governance/compliance-statement-2014_en.pdf/_jcr_content/renditions/original.media_file.download_attachment.file/compliance-statement-2014_en.pdf
# -------------------- /content/dam/fraport-company/documents/investoren/eng/corporate-governance/entsprechenserklaerung_2014_en.pdf/_jcr_content/renditions/original.media_file.download_attachment.file/entsprechenserklaerung_2014_en.pdf
# -------------------- /content/dam/fraport-company/documents/investoren/eng/corporate-governance/entsprechenserklaerung_2013_en.pdf/_jcr_content/renditions/original.media_file.download_attachment.file/entsprechenserklaerung_2013_en.pdf
# -------------------- /content/dam/fraport-company/documents/investoren/eng/corporate-governance/englische-entsprechenserklaerung-stand-14-12-2012.pdf/_jcr_content/renditions/original.media_file.download_attachment.file/englische-entsprechenserklaerung-stand-14-12-2012.pdf
# -------------------- /content/dam/fraport-company/documents/investoren/eng/corporate-governance/entsprechenserklaerung-2011.pdf/_jcr_content/renditions/original.media_file.download_attachment.file/entsprechenserklaerung-2011.pdf
# /content/dam/fraport-company/documents/investoren/eng/corporate-governance/entsprechungserklaerung2-2010.pdf/_jcr_content/renditions/original.media_file.download_attachment.file/entsprechungserklaerung2-2010.pdf
# /content/dam/fraport-company/documents/investoren/eng/corporate-governance/entsprechungserklaerung1-2010.pdf/_jcr_content/renditions/original.media_file.download_attachment.file/entsprechungserklaerung1-2010.pdf
# /content/dam/fraport-company/documents/investoren/eng/corporate-governance/entsprechungserklaerung-2009.pdf/_jcr_content/renditions/original.media_file.download_attachment.file/entsprechungserklaerung-2009.pdf
# /content/dam/fraport-company/documents/investoren/eng/corporate-governance/entsprechungserklaerung-2008.pdf/_jcr_content/renditions/original.media_file.download_attachment.file/entsprechungserklaerung-2008.pdf
# /content/dam/fraport-company/documents/investoren/eng/corporate-governance/entsprechungserklaerung-2007.pdf/_jcr_content/renditions/original.media_file.download_attachment.file/entsprechungserklaerung-2007.pdf
# /content/dam/fraport-company/documents/investoren/eng/corporate-governance/entsprechungserklaerung-2009.pdf/_jcr_content/renditions/original.media_file.download_attachment.file/entsprechungserklaerung-2009.pdf
# /content/dam/fraport-company/documents/investoren/eng/corporate-governance/entsprechungserklaerung-2-2005.pdf/_jcr_content/renditions/original.media_file.download_attachment.file/entsprechungserklaerung-2-2005.pdf
# /content/dam/fraport-company/documents/investoren/eng/corporate-governance/entsprechungserklaerung-1-2005.pdf/_jcr_content/renditions/original.media_file.download_attachment.file/entsprechungserklaerung-1-2005.pdf
# /content/dam/fraport-company/documents/investoren/eng/corporate-governance/entsprechungserklaerung-2004.pdf/_jcr_content/renditions/original.media_file.download_attachment.file/entsprechungserklaerung-2004.pdf
# /content/dam/fraport-company/documents/investoren/eng/corporate-governance/entsprechungserklaerung-2003.pdf/_jcr_content/renditions/original.media_file.download_attachment.file/entsprechungserklaerung-2003.pdf
# /content/dam/fraport-company/documents/investoren/eng/corporate-governance/entsprechungserklaerung-2002.pdf/_jcr_content/renditions/original.media_file.download_attachment.file/entsprechungserklaerung-2002.pdf
# -------------------- /en/our-group/about-us/contact-form-fraport-ag.html
# -------------------- /en/our-group.html
# -------------------- /en/business-areas.html
# -------------------- /en/investors.html
# -------------------- /en/environment.html
# -------------------- /en/newsroom.html
# -------------------- https://www.frankfurt-airport.com/de.html
# -------------------- /en/tools/imprint.html
# -------------------- /en/tools/legal-information.html
# -------------------- /en/our-group/data-protection-statement.html
# -------------------- /en/business-areas/services/purchasing-and-contracting/guidelines-and-payment-terms.html
# -------------------- https://www.facebook.com/FrankfurtAirport?fref=ts
# -------------------- https://www.instagram.com/frankfurtairport
# -------------------- https://www.youtube.com/user/fraportundfra
# -------------------- http://www.twitter.com/Airport_FRA

# %%
response = requests.get('https://www.fraport.com/en/investors/corporate-governance.html', timeout=2)
soup= BeautifulSoup(response.text, "html.parser")

# %%
"entsprechungserklaerung" in "file:///C:/Users/Subair/Downloads/2020_Entsprechenserkl%C3%A4rung.pdf"
# Out:
# False
